# %% [markdown]
# Hola esto es un texto $(x_n)_{n\in\mathbb N}$
#
# $$\int_0^1 x^2\ dx$$

# %% [markdown]
# Hola que tal, esto es un ~~ejemplo~~
#
# Para escribir listas:
#
# * Manzanas
# * Peras
# * Limones
#
# 1. Primero
# 2. Segundo
# 3. Tercero
